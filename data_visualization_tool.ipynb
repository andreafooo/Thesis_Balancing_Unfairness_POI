# %%
import pandas as pd
from globals import BASE_DIR, wikimedia_headers
import json
import geopandas as gpd
from shapely.geometry import Point
import folium
import requests
from branca.element import Element
from folium.plugins import TreeLayerControl
from bs4 import BeautifulSoup
import html


available_datasets = ["gowalla"]
top_k_eval = 10

# Stockholm sample
coordinates=(18.0686, 59.3290)

# %%
def get_wikimedia_images_at_point(lat, lon, headers=wikimedia_headers):
    url = (
        "https://commons.wikimedia.org/w/api.php"
        "?format=json"
        "&action=query"
        "&generator=geosearch"
        "&ggsprimary=all"
        "&ggsnamespace=6"
        "&ggsradius=200"
        "&ggscoord=" + str(lat) + "|" + str(lon) +
        "&ggslimit=10"
        "&prop=imageinfo"
        "&iiprop=extmetadata|url"
        "&iilimit=10"
        "&iiurlwidth=1200"
        "&iiurlheight=1200"
    )

    images = []
    call = requests.get(url, headers=headers)

    if call.status_code == 200:
        response = call.json()
        if 'query' in response and 'pages' in response['query']:
            for page in response['query']['pages']:
                page_data = response['query']['pages'][page]
                image_info = page_data['imageinfo'][0]
                extmeta = image_info.get('extmetadata', {})

                license_name = extmeta.get('LicenseShortName', {}).get('value', '')
                license_url = extmeta.get('LicenseUrl', {}).get('value', '')
                author = extmeta.get('Artist', {}).get('value', '')
                credit = extmeta.get('Credit', {}).get('value', '')
                description = extmeta.get('ImageDescription', {}).get('value', '')

                images.append({
                    'id': page_data['pageid'],
                    'title': page_data.get('title', ''),
                    'photo_url_thumb': image_info.get('thumburl', ''),
                    'photo_url_medium': '',  # Optional field for larger sizes
                    'description': description,
                    'author': author,
                    'credit': credit,
                    'license': license_name,
                    'license_url': license_url,
                    'info_url': image_info.get('descriptionurl', ''),
                    'info_raw': image_info,
                    'source': 'wikimedia'
                })
    else:
        print('Ein Fehler ist aufgetreten beim Abruf der Wikimedia-Bilder.')

    return images, call

# %%
def unstack_recommendations(df):
    unstacked_df = df.explode(["item_id:token"]).reset_index(drop=True)
    return unstacked_df

# %%
def top_k_to_df(recommender_dir, top_k_eval=top_k_eval):
    with open(recommender_dir) as f:
        data = json.load(f)

    base_recommendations = []

    for user, items in data.items():
        for item in items:
            base_recommendations.append({
                "user_id:token": user,
                "item_id:token": item
            })


    base_df = pd.DataFrame(base_recommendations)
    base_df = unstack_recommendations(base_df)

    df = base_df.groupby('user_id:token').head(top_k_eval)

    return df

# %%
def group_user_events(user_events, user_groups):
    stats = {}
    for group in user_groups.keys():
        stats[group] = {}
        user_events_group = user_events.copy()
        user_events_group = user_events_group.loc[user_events_group['user_id:token'].isin(user_groups[group])]
        user_dist = user_events_group["user_id:token"].value_counts()
        stats[group]["num_users"] = user_dist.shape[0]
        stats[group]["mean_checkins"] = user_events_group["user_id:token"].value_counts().mean()
        stats[group]["min_checkins"] = user_events_group["user_id:token"].value_counts().min()
        stats[group]["max_checkins"] = user_events_group["user_id:token"].value_counts().max()
        item_dist = user_events_group["item_id:token"].value_counts()
        stats[group]["num_items"] = item_dist.shape[0]
        stats[group]["sparsity"] = 1 - len(user_events_group) / (len(user_events_group["user_id:token"].unique()) * len(user_events_group["item_id:token"].unique()))

    return stats

# %%
full_stats = {}
for dataset in available_datasets:
    # Stays the same across all models 
    train_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.train.inter", sep="\t")
    test_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.test.inter", sep="\t")
    valid_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.valid.inter", sep="\t")

    train_data = pd.concat([train_data, valid_data])
    user_group_dir = f"{BASE_DIR}{dataset}_dataset/{dataset}_user_id_popularity.json"
    with open(user_group_dir) as f:
        user_groups = json.load(f)

    poi_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_capri/poiCoos.txt", sep="\t", header=None, names=["item_id:token", "lat:float", "lon:float"])
    poi_data["item_id:token"] = poi_data["item_id:token"].astype(str) + "_x"

    all_user_ids = (
    set(user_groups["high"])
    | set(user_groups["medium"])
    | set(user_groups["low"])
    )

    value_counts = train_data["item_id:token"].value_counts().reset_index()
    value_counts.columns = ["item_id:token", "count"]
    value_counts["item_pop"] = value_counts["count"] / len(value_counts)
    train_data = train_data.merge(
        value_counts[["item_id:token", "item_pop"]],
        on="item_id:token",
        how="left",
    )

    user_events = pd.concat([train_data, test_data])

# %% [markdown]
# #### Turn the POI data into a Geodataframe and perform filtering

# %%
def geolocation_poi_filter(poi_data, coordinates=(18.0680, 59.3293) , radius=20000, train_data=train_data):

    gdf = gpd.GeoDataFrame(
        poi_data,
        geometry=gpd.points_from_xy(poi_data["lon:float"], poi_data["lat:float"]),
        crs="EPSG:4326"  # WGS84
    )

    gdf = gdf.to_crs("EPSG:3857")
    stockholm_point = gpd.GeoSeries(
        [Point(coordinates)], crs="EPSG:4326"
    ).to_crs("EPSG:3857")
    buffer = stockholm_point.buffer(radius)  # 20 km buffer default

    filtered_gdf = gdf[gdf.geometry.within(buffer.unary_union)]
    filtered_gdf = filtered_gdf.to_crs("EPSG:4326")

    relevant_items = filtered_gdf["item_id:token"].unique().tolist()

    relevant_train_data = train_data[train_data["item_id:token"].isin(relevant_items)]

    relevant_users = relevant_train_data["user_id:token"].unique().tolist()

    filtered_gdf = pd.merge(filtered_gdf, relevant_train_data[["item_id:token", "item_pop"]], on="item_id:token", how="left")
    filtered_gdf = filtered_gdf.drop_duplicates(subset=["item_id:token"])

    return filtered_gdf, relevant_train_data, relevant_users

# %%
filtered_gdf, relevant_train_data, relevant_users = geolocation_poi_filter(poi_data, coordinates, train_data=train_data)
# Out:
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_26247/4030698262.py:15: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   filtered_gdf = gdf[gdf.geometry.within(buffer.unary_union)]

# %%
filtered_gdf.sort_values("item_pop", ascending=False).head(10)
# Out:
#      item_id:token  lat:float  lon:float                   geometry  item_pop
# 241         1151_x  59.330158  18.058079  POINT (18.05808 59.33016)  0.020765
# 771         1204_x  59.320201  18.071169   POINT (18.07117 59.3202)  0.008550
# 1161        2001_x  59.332243  18.061920  POINT (18.06192 59.33224)  0.006786
# 2547         962_x  59.323196  18.067038   POINT (18.06704 59.3232)  0.006786
# 62          1127_x  59.330935  18.059249  POINT (18.05925 59.33093)  0.006379
# 2853        1352_x  59.299108  18.080760  POINT (18.08076 59.29911)  0.006107
# 11          1096_x  59.334317  18.062704   POINT (18.0627 59.33432)  0.005565
# 2279        6123_x  59.323278  18.097186  POINT (18.09719 59.32328)  0.004750
# 602          919_x  59.330825  18.071780  POINT (18.07178 59.33083)  0.004615
# 193         1674_x  59.333096  18.069044   POINT (18.06904 59.3331)  0.004479

# %% [markdown]
# # User Groups
#
# ### Stockholm Sample
# (Gowalla + coordinates=(18.0686, 59.3293) & radius=20000)
# * user g1 = 481_x
# * user g2 = 1023_x
# * user g3 = 130_x
#
# * BPR: gowalla_sample-BPR-Dec-19-2024_20-23-30/baseline
# * BPR CP: gowalla_sample-BPR-Dec-19-2024_20-23-30/cp
# * LORE: gowalla_sample-contextpoi-LORE-Sep-16-2024_09-00-00/baseline

# %%
# training data for the 3 users

train_g1 = relevant_train_data.loc[relevant_train_data["user_id:token"] == "481_x"]
train_g2 = relevant_train_data.loc[relevant_train_data["user_id:token"] == "1023_x"]
train_g3 = relevant_train_data.loc[relevant_train_data["user_id:token"] == "130_x"]

# %%
# baseline recommendations for the 3 users
baseline = top_k_to_df(f"{BASE_DIR}{dataset}_dataset/recommendations/{dataset}_sample-BPR-Dec-19-2024_20-23-30/baseline/top_k_recommendations.json")
cp = top_k_to_df(f"{BASE_DIR}{dataset}_dataset/recommendations/{dataset}_sample-BPR-Dec-19-2024_20-23-30/cp/top_k_recommendations.json")
context = top_k_to_df(f"{BASE_DIR}{dataset}_dataset/recommendations/{dataset}_sample-contextpoi-LORE-Sep-16-2024_09-00-00/baseline/top_k_recommendations.json")

# %%
user_samples = {"HighPop": "481_x", "MedPop": "1023_x", "LowPop": "130_x"}
for key, item in user_samples.items():
    print(key)
# Out:
# HighPop
# MedPop
# LowPop

# %%
relevant_train_data
# Out:
#       user_id:token item_id:token  checkin_count:float  item_pop
# 418          1016_x        1125_x                    1  0.001357
# 419          1016_x        1652_x                    1  0.001764
# 420          1016_x        1222_x                    2  0.001629
# 421          1016_x         919_x                    1  0.004615
# 422          1016_x        1207_x                    1  0.000814
# ...             ...           ...                  ...       ...
# 42330          99_x        4200_x                    1  0.000679
# 42331          99_x        1685_x                    1  0.003393
# 42339          99_x        5134_x                    1  0.000407
# 42340          99_x        1818_x                    1  0.000271
# 42341          99_x        4005_x                    1  0.000543
#
# [5410 rows x 4 columns]

# %%
def parse_author(author_html):
    soup = BeautifulSoup(author_html, "html.parser")
    a_tag = soup.find("a")
    if a_tag:
        name = a_tag.text.strip()
        href = a_tag.get("href", "").strip()
        if href.startswith("http"):
            url = href
        else:
            url = "https:" + href
        return name, url
    return None, None

# %%
def data_prep_visualization(filtered_gdf, inters, user_samples):
    data_list = []
    
    for user_group, user_id in user_samples.items():
        user_inters = inters.loc[inters["user_id:token"] == user_id]
        relevant_items = filtered_gdf.loc[filtered_gdf["item_id:token"].isin(user_inters["item_id:token"])]
        relevant_items = relevant_items.reset_index(drop=True)

        photo_urls_list = []
        
        for _, row in relevant_items.iterrows():
            lat, lon = row.geometry.y, row.geometry.x  # lat, lon
            images, _ = get_wikimedia_images_at_point(lat, lon, wikimedia_headers)
            
            photo_infos = []
            for image in images:
                author_name, author_url = parse_author(image.get("author", ""))
                photo_infos.append({
                    "photo_url_thumb": image.get("photo_url_thumb"),
                    "author_name": author_name,
                    "author_url": author_url,
                    "credit": BeautifulSoup(image.get("credit", ""), "html.parser").text.strip(),
                    "license": image.get("license"),
                    "license_url": image.get("license_url"),

                    
                })
            photo_urls_list.append(photo_infos)

        relevant_items["photo_infos"] = photo_urls_list
        data_list.append(relevant_items)

    return data_list

# %%
training_data_list = data_prep_visualization(filtered_gdf, relevant_train_data, user_samples)

# %%
training_data_list[0]["photo_infos"].values.tolist()
# Out:
# [[{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Stockholms_centralstation_ljuskrona.JPG/1200px-Stockholms_centralstation_ljuskrona.JPG',
#    'author_name': 'Jssfrk',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Jssfrk',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Stockholms_centralstation_interi%C3%B6r.JPG/1200px-Stockholms_centralstation_interi%C3%B6r.JPG',
#    'author_name': 'Jssfrk',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Jssfrk',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Stockholm_Centralstation-lockers.jpg/1200px-Stockholm_Centralstation-lockers.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/20180622_Sto.C_6316_%2848410498051%29.jpg/1200px-20180622_Sto.C_6316_%2848410498051%29.jpg',
#    'author_name': 'Ray Swi-hymn',
#    'author_url': 'https://www.flickr.com/people/46218178@N02',
#    'credit': '20180622_Sto.C_6316',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/20180623_Stockholm_6378_%2848410834921%29.jpg/1200px-20180623_Stockholm_6378_%2848410834921%29.jpg',
#    'author_name': 'Ray Swi-hymn',
#    'author_url': 'https://www.flickr.com/people/46218178@N02',
#    'credit': '20180623_Stockholm_6378',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Stockholm_Central%2C_Stani%C4%8Dn%C3%AD_hala_%28leden_2024%29.jpg/1200px-Stockholm_Central%2C_Stani%C4%8Dn%C3%AD_hala_%28leden_2024%29.jpg',
#    'author_name': 'Vojtasekd',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Vojtasekd',
#    'credit': 'Own work',
#    'license': 'CC BY 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/MTRX%2C_Stockholm_Central_-_20231022_-_14.jpg/1200px-MTRX%2C_Stockholm_Central_-_20231022_-_14.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Stockholm_Centralstation_-_20240831_-_02.jpg/1200px-Stockholm_Centralstation_-_20240831_-_02.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/89/Arlanda_Express%2C_Stockholm_Centralstation_-_20240831_-_03.jpg/1200px-Arlanda_Express%2C_Stockholm_Centralstation_-_20240831_-_03.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Stockholm_Centralstation_-_20240831_-_01.jpg/1200px-Stockholm_Centralstation_-_20240831_-_01.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/f/f8/Stockholms_innerstad_-_KMB_-_16001000195624.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': 'Erik Claesson / Kulturmiljöbild, Riksantikvarieämbetet\n\n\n\n\n\nThis file was provided to Wikimedia Commons by the Swedish National Heritage Board as part of the cooperation project Connected Open Heritage with Wikimedia Sverige.\n\n\n\n\n\n\n\nThis file was made available by Riksantikvarieämbetet as part of the Connected Open Heritage project. The project is led by Wikimedia Sverige in cooperation with UNESCO, Wikimedia Italia and Cultural Heritage without Borders and is financed by a project grant from the Culture Foundation of the Swedish Postcode Lottery.',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/d/d2/Stockholms_innerstad_-_KMB_-_16001000195644.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': 'Erik Claesson / Kulturmiljöbild, Riksantikvarieämbetet\n\n\n\n\n\nThis file was provided to Wikimedia Commons by the Swedish National Heritage Board as part of the cooperation project Connected Open Heritage with Wikimedia Sverige.\n\n\n\n\n\n\n\nThis file was made available by Riksantikvarieämbetet as part of the Connected Open Heritage project. The project is led by Wikimedia Sverige in cooperation with UNESCO, Wikimedia Italia and Cultural Heritage without Borders and is financed by a project grant from the Culture Foundation of the Swedish Postcode Lottery.',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/42/Stockholm_118_%2831437813945%29.jpg/1200px-Stockholm_118_%2831437813945%29.jpg',
#    'author_name': 'Егор Журавлёв',
#    'author_url': 'https://www.flickr.com/people/142171772@N06',
#    'credit': 'Stockholm_118',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Oniscus_asellus_102391724.jpg/960px-Oniscus_asellus_102391724.jpg',
#    'author_name': 'jensu',
#    'author_url': 'https://www.inaturalist.org/users/2041659',
#    'credit': 'https://www.inaturalist.org/photos/102391724',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/0089Stockholms_slott.jpg/1200px-0089Stockholms_slott.jpg',
#    'author_name': 'L.G.foto',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:L.G.foto&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022a.jpg/1200px-Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022a.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/36/Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022b.jpg/1200px-Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022b.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/Ferenc_G%C3%B6nd%C3%B6r_showing_a_recording_studio_at_Sveriges_Radio%2C_Stockholm.jpg/1200px-Ferenc_G%C3%B6nd%C3%B6r_showing_a_recording_studio_at_Sveriges_Radio%2C_Stockholm.jpg',
#    'author_name': 'W.carter',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:W.carter',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ad/The_very_silent_room_at_Sveriges_Radio%2C_Stockholm.jpg/1200px-The_very_silent_room_at_Sveriges_Radio%2C_Stockholm.jpg',
#    'author_name': 'W.carter',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:W.carter',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/The_records_archive%2C_Grammofonarkivet%2C_at_Sveriges_Radio%2C_Stockholm.jpg/1200px-The_records_archive%2C_Grammofonarkivet%2C_at_Sveriges_Radio%2C_Stockholm.jpg',
#    'author_name': 'W.carter',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:W.carter',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c0/B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012a.jpg/960px-B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012a.jpg',
#    'author_name': 'MjauMjauMjauMjau',
#    'author_url': 'https://www.flickr.com/people/72869172@N08',
#    'credit': 'Båt med figur, omgiven av en ram',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ef/B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012b.jpg/960px-B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012b.jpg',
#    'author_name': 'MjauMjauMjauMjau',
#    'author_url': 'https://www.flickr.com/people/72869172@N08',
#    'credit': 'Båt med figur, omgiven av en ram',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Liljeholmens_grill.JPG/1200px-Liljeholmens_grill.JPG',
#    'author_name': 'Erik Brattlöf',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c6/Skylt_p%C3%A5_Golv%2C_Gallerian_Liljeholmen.jpg/960px-Skylt_p%C3%A5_Golv%2C_Gallerian_Liljeholmen.jpg',
#    'author_name': 'IngimarE',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:IngimarE',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Nybohovshissen%2C_20240210_-_11.jpg/1200px-Nybohovshissen%2C_20240210_-_11.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Nybohovshissen%2C_20240210_-_10.jpg/1200px-Nybohovshissen%2C_20240210_-_10.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Liljeholmen_tunnelbana%2C_SL_C30%2C_20240210_-_14.jpg/1200px-Liljeholmen_tunnelbana%2C_SL_C30%2C_20240210_-_14.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Liljeholmen%2C_CX-tunnelbana%2C_20240210_-_37.jpg/960px-Liljeholmen%2C_CX-tunnelbana%2C_20240210_-_37.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/85/Liljeholmen%2C_SL_C30_tunnelbana%2C_20240210_-_61.jpg/1200px-Liljeholmen%2C_SL_C30_tunnelbana%2C_20240210_-_61.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Czech_bernard_beer_in_Sweden.jpg/960px-Czech_bernard_beer_in_Sweden.jpg',
#    'author_name': 'Aysello',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Aysello&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/9/96/Gullmarsplans_torg_1.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': '',
#    'license': 'CC BY-SA 2.5',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.5'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/Gullmarsplans_torg_2.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': '',
#    'license': 'CC BY-SA 2.5',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.5'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/e/e4/Gullmarsplans_torg_3.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': '',
#    'license': 'CC BY-SA 2.5',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.5'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/EU-SE-Stockholm-Gullmarsplan_001.JPG/1200px-EU-SE-Stockholm-Gullmarsplan_001.JPG',
#    'author_name': 'Dmitry G',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Dmitry_G',
#    'credit': 'Own work',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/EU-SE-Stockholm-Gullmarsplan_002.JPG/1200px-EU-SE-Stockholm-Gullmarsplan_002.JPG',
#    'author_name': 'Dmitry G',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Dmitry_G',
#    'credit': 'Own work',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Grilltorget%2C_Gullmarsplan%2C_Stockholm.jpg/1200px-Grilltorget%2C_Gullmarsplan%2C_Stockholm.jpg',
#    'author_name': 'golonka66',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Gullmarsplan-2.jpg/1200px-Gullmarsplan-2.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Gullmarsplan-1.jpg/1200px-Gullmarsplan-1.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg/1200px-Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg',
#    'author_name': 'johanarthur',
#    'author_url': 'https://unsplash.com/@johanarthur',
#    'credit': 'https://unsplash.com/photos/eVQxIh6Psh0\nImage at the Wayback Machine\n\nGallery at the Wayback Machine',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/C20F_2000_Elvira.jpg/1200px-C20F_2000_Elvira.jpg',
#    'author_name': 'Anton Lidström',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Antonlidstrom71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/EU-SE-Stockholm-Gullmarsplan_001.JPG/1200px-EU-SE-Stockholm-Gullmarsplan_001.JPG',
#    'author_name': 'Dmitry G',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Dmitry_G',
#    'credit': 'Own work',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/GasregulatorVolvo-1.JPG/1200px-GasregulatorVolvo-1.JPG',
#    'author_name': 'Patrik Nylin',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Pny71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/28/GasregulatorVolvo-2.JPG/1200px-GasregulatorVolvo-2.JPG',
#    'author_name': 'Patrik Nylin',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Pny71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm.jpg/1200px-Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm.jpg',
#    'author_name': 'golonka66',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/95/Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm_2.jpg/1200px-Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm_2.jpg',
#    'author_name': 'golonka66',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Gullmarsplan-2.jpg/1200px-Gullmarsplan-2.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Gullmarsplan-1.jpg/1200px-Gullmarsplan-1.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg/1200px-Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg',
#    'author_name': 'johanarthur',
#    'author_url': 'https://unsplash.com/@johanarthur',
#    'credit': 'https://unsplash.com/photos/eVQxIh6Psh0\nImage at the Wayback Machine\n\nGallery at the Wayback Machine',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/C20F_2000_Elvira.jpg/1200px-C20F_2000_Elvira.jpg',
#    'author_name': 'Anton Lidström',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Antonlidstrom71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/Sp%C3%A4rren_i_Gullmarsplan%2C_20220930.jpg/1200px-Sp%C3%A4rren_i_Gullmarsplan%2C_20220930.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Angie_Stone_2010.jpg/1200px-Angie_Stone_2010.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'Flickr: IMG_1257',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/11/Berns_IMG_9205_%284399640858%29.jpg/1200px-Berns_IMG_9205_%284399640858%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9205-1',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Berns_IMG_9127_%284398877683%29.jpg/1200px-Berns_IMG_9127_%284398877683%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9127',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/Berns_IMG_9136_%284399642780%29.jpg/1200px-Berns_IMG_9136_%284399642780%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9136',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/37/Berns_IMG_9230_%284398809801%29.jpg/1200px-Berns_IMG_9230_%284398809801%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9230',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Berns_IMG_9220_%284398834113%29.jpg/1200px-Berns_IMG_9220_%284398834113%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9220',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Berns_IMG_1247_%284399639040%29.jpg/1200px-Berns_IMG_1247_%284399639040%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_1247',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Berns_IMG_9219_%284398841579%29.jpg/1200px-Berns_IMG_9219_%284398841579%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9219',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Berns_IMG_1272_%284398851919%29.jpg/1200px-Berns_IMG_1272_%284398851919%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_1272',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Weyes_Blood_at_Berns%2C_Stockholm%2C_Sweden.jpg/977px-Weyes_Blood_at_Berns%2C_Stockholm%2C_Sweden.jpg',
#    'author_name': 'Juchanwonderland',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Juchanwonderland&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/2012_Ssangyong_Actyons_Sports_D200S_%28Stockholm%29.jpg/1200px-2012_Ssangyong_Actyons_Sports_D200S_%28Stockholm%29.jpg',
#    'author_name': 'Mr.choppers',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Mr.choppers',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/2012_Ssangyong_Actyons_Sports_D200S_rear.jpg/1200px-2012_Ssangyong_Actyons_Sports_D200S_rear.jpg',
#    'author_name': 'Mr.choppers',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Mr.choppers',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/f/f5/Folkungagatan_1963.jpg',
#    'author_name': 'Håkan Trapp',
#    'author_url': 'https://www.wikidata.org/wiki/Q6214850',
#    'credit': 'http://www.stockholmskallan.se/Soksida/Post/?nid=27580',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/9/95/B%C3%A5tsmannen.jpg',
#    'author_name': 'Mamma p',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Mamma_p&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Katarina-Sofia%2C_S%C3%B6dermalm%2C_Stockholm%2C_Sweden_-_panoramio_%282%29.jpg/1200px-Katarina-Sofia%2C_S%C3%B6dermalm%2C_Stockholm%2C_Sweden_-_panoramio_%282%29.jpg',
#    'author_name': 'victorvilkancis@gmai…',
#    'author_url': 'https://web.archive.org/web/20161026054557/http://www.panoramio.com/user/6848960?with_photo_id=70414358',
#    'credit': 'https://web.archive.org/web/20161026054555/http://www.panoramio.com/photo/70414358',
#    'license': 'CC BY 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Tj%C3%A4rhovsgatan_7%2C_2017.jpg/1200px-Tj%C3%A4rhovsgatan_7%2C_2017.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Tj%C3%A4rhovsgatan_7%2C_2017b.jpg/1200px-Tj%C3%A4rhovsgatan_7%2C_2017b.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d1/Sifwertska_kasernen_april%2C_2019e.jpg/1200px-Sifwertska_kasernen_april%2C_2019e.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Dagakarlen_38.jpg/960px-Dagakarlen_38.jpg',
#    'author_name': 'Jimandersson1',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Jimandersson1&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ae/%C3%96stg%C3%B6tagatan-Folkungagatan.jpg/960px-%C3%96stg%C3%B6tagatan-Folkungagatan.jpg',
#    'author_name': 'VisbyStar',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:VisbyStar',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Dansens_hus01.jpg/1200px-Dansens_hus01.jpg',
#    'author_name': 'Esquilo',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Esquilo',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Barnhusgatan_8.JPG/1200px-Barnhusgatan_8.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Folkets_hus%2C_Stockholm_2014.JPG/1200px-Folkets_hus%2C_Stockholm_2014.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Kongresser_Konserter_Utst%C3%A4llningar_%2815177592350%29.jpg/1200px-Kongresser_Konserter_Utst%C3%A4llningar_%2815177592350%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Kongresser Konserter Utställningar',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Dansens_Hus_%2815893044326%29.jpg/1200px-Dansens_Hus_%2815893044326%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Dansens Hus',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Barnhusgatan_%2815733097387%29.jpg/1200px-Barnhusgatan_%2815733097387%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Barnhusgatan',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Dansens_Hus_%2815296599384%29.jpg/1200px-Dansens_Hus_%2815296599384%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Dansens Hus',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Barnhuset_20%2C_Stockholm.JPG/1200px-Barnhuset_20%2C_Stockholm.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Stockholm%2C_Sweden_%28Unsplash_3aVlWP-7bg8%29.jpg/1200px-Stockholm%2C_Sweden_%28Unsplash_3aVlWP-7bg8%29.jpg',
#    'author_name': 'mikael_k',
#    'author_url': 'https://unsplash.com/@mikael_k',
#    'credit': 'https://unsplash.com/photos/3aVlWP-7bg8\nImage at the Wayback Machine\n\nGallery at the Wayback Machine',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Folkets_hus%2C_Stockholm_2018.jpg/1200px-Folkets_hus%2C_Stockholm_2018.jpg',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/Filadelfiakyrkan_stockholm.JPG/1200px-Filadelfiakyrkan_stockholm.JPG',
#    'author_name': 'Haxpett',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Haxpett',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Filadelfiakyrkan_stockholm_framsida.JPG/1200px-Filadelfiakyrkan_stockholm_framsida.JPG',
#    'author_name': 'Haxpett',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Haxpett',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/R%C3%B6rstrandsgatan_4-6.JPG/1200px-R%C3%B6rstrandsgatan_4-6.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/R%C3%B6rstrandsgrillen.JPG/1200px-R%C3%B6rstrandsgrillen.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Stengodset_24.JPG/1200px-Stengodset_24.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/58/Gjutaren_26.JPG/1200px-Gjutaren_26.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/View_of_northern_Kungsholmen_-_panoramio.jpg/1200px-View_of_northern_Kungsholmen_-_panoramio.jpg',
#    'author_name': 'Knutars',
#    'author_url': 'https://web.archive.org/web/20161011041008/http://www.panoramio.com/user/637704?with_photo_id=3143618',
#    'credit': 'https://web.archive.org/web/20161011041006/http://www.panoramio.com/photo/3143618',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Stengodset_18%2C_Stockholm.JPG/1200px-Stengodset_18%2C_Stockholm.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Bakgrunden_i_fokus_-_Flickr_-_nilsw.jpg/960px-Bakgrunden_i_fokus_-_Flickr_-_nilsw.jpg',
#    'author_name': 'Nils Weinander',
#    'author_url': 'https://www.flickr.com/people/42159086@N08',
#    'credit': 'Bakgrunden i fokus',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fc/R%C3%B6rstrands_Porslinsfabriker_%286305359137%29.jpg/1200px-R%C3%B6rstrands_Porslinsfabriker_%286305359137%29.jpg',
#    'author_name': 'Tekniska museet',
#    'author_url': 'https://www.flickr.com/people/59292810@N07',
#    'credit': 'Rörstrands Porslinsfabriker',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'}]]

# %%
baseline_list = data_prep_visualization(filtered_gdf, baseline, user_samples)
cp_list = data_prep_visualization(filtered_gdf, cp, user_samples)
#upd_list = data_prep_visualization(filtered_gdf, upd, user_samples)
context_list = data_prep_visualization(filtered_gdf, context, user_samples)

# %%
training_data_list[0]["photo_infos"].values.tolist()
# Out:
# [[{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Stockholms_centralstation_ljuskrona.JPG/1200px-Stockholms_centralstation_ljuskrona.JPG',
#    'author_name': 'Jssfrk',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Jssfrk',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Stockholms_centralstation_interi%C3%B6r.JPG/1200px-Stockholms_centralstation_interi%C3%B6r.JPG',
#    'author_name': 'Jssfrk',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Jssfrk',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Stockholm_Centralstation-lockers.jpg/1200px-Stockholm_Centralstation-lockers.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/20180622_Sto.C_6316_%2848410498051%29.jpg/1200px-20180622_Sto.C_6316_%2848410498051%29.jpg',
#    'author_name': 'Ray Swi-hymn',
#    'author_url': 'https://www.flickr.com/people/46218178@N02',
#    'credit': '20180622_Sto.C_6316',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/20180623_Stockholm_6378_%2848410834921%29.jpg/1200px-20180623_Stockholm_6378_%2848410834921%29.jpg',
#    'author_name': 'Ray Swi-hymn',
#    'author_url': 'https://www.flickr.com/people/46218178@N02',
#    'credit': '20180623_Stockholm_6378',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Stockholm_Central%2C_Stani%C4%8Dn%C3%AD_hala_%28leden_2024%29.jpg/1200px-Stockholm_Central%2C_Stani%C4%8Dn%C3%AD_hala_%28leden_2024%29.jpg',
#    'author_name': 'Vojtasekd',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Vojtasekd',
#    'credit': 'Own work',
#    'license': 'CC BY 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/MTRX%2C_Stockholm_Central_-_20231022_-_14.jpg/1200px-MTRX%2C_Stockholm_Central_-_20231022_-_14.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Stockholm_Centralstation_-_20240831_-_02.jpg/1200px-Stockholm_Centralstation_-_20240831_-_02.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/89/Arlanda_Express%2C_Stockholm_Centralstation_-_20240831_-_03.jpg/1200px-Arlanda_Express%2C_Stockholm_Centralstation_-_20240831_-_03.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Stockholm_Centralstation_-_20240831_-_01.jpg/1200px-Stockholm_Centralstation_-_20240831_-_01.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/f/f8/Stockholms_innerstad_-_KMB_-_16001000195624.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': 'Erik Claesson / Kulturmiljöbild, Riksantikvarieämbetet\n\n\n\n\n\nThis file was provided to Wikimedia Commons by the Swedish National Heritage Board as part of the cooperation project Connected Open Heritage with Wikimedia Sverige.\n\n\n\n\n\n\n\nThis file was made available by Riksantikvarieämbetet as part of the Connected Open Heritage project. The project is led by Wikimedia Sverige in cooperation with UNESCO, Wikimedia Italia and Cultural Heritage without Borders and is financed by a project grant from the Culture Foundation of the Swedish Postcode Lottery.',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/d/d2/Stockholms_innerstad_-_KMB_-_16001000195644.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': 'Erik Claesson / Kulturmiljöbild, Riksantikvarieämbetet\n\n\n\n\n\nThis file was provided to Wikimedia Commons by the Swedish National Heritage Board as part of the cooperation project Connected Open Heritage with Wikimedia Sverige.\n\n\n\n\n\n\n\nThis file was made available by Riksantikvarieämbetet as part of the Connected Open Heritage project. The project is led by Wikimedia Sverige in cooperation with UNESCO, Wikimedia Italia and Cultural Heritage without Borders and is financed by a project grant from the Culture Foundation of the Swedish Postcode Lottery.',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/42/Stockholm_118_%2831437813945%29.jpg/1200px-Stockholm_118_%2831437813945%29.jpg',
#    'author_name': 'Егор Журавлёв',
#    'author_url': 'https://www.flickr.com/people/142171772@N06',
#    'credit': 'Stockholm_118',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Oniscus_asellus_102391724.jpg/960px-Oniscus_asellus_102391724.jpg',
#    'author_name': 'jensu',
#    'author_url': 'https://www.inaturalist.org/users/2041659',
#    'credit': 'https://www.inaturalist.org/photos/102391724',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/0089Stockholms_slott.jpg/1200px-0089Stockholms_slott.jpg',
#    'author_name': 'L.G.foto',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:L.G.foto&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022a.jpg/1200px-Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022a.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/36/Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022b.jpg/1200px-Kungl_G%C3%B6ta_Livgarde_minnessten%2C_juni_2022b.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/Ferenc_G%C3%B6nd%C3%B6r_showing_a_recording_studio_at_Sveriges_Radio%2C_Stockholm.jpg/1200px-Ferenc_G%C3%B6nd%C3%B6r_showing_a_recording_studio_at_Sveriges_Radio%2C_Stockholm.jpg',
#    'author_name': 'W.carter',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:W.carter',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ad/The_very_silent_room_at_Sveriges_Radio%2C_Stockholm.jpg/1200px-The_very_silent_room_at_Sveriges_Radio%2C_Stockholm.jpg',
#    'author_name': 'W.carter',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:W.carter',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/The_records_archive%2C_Grammofonarkivet%2C_at_Sveriges_Radio%2C_Stockholm.jpg/1200px-The_records_archive%2C_Grammofonarkivet%2C_at_Sveriges_Radio%2C_Stockholm.jpg',
#    'author_name': 'W.carter',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:W.carter',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c0/B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012a.jpg/960px-B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012a.jpg',
#    'author_name': 'MjauMjauMjauMjau',
#    'author_url': 'https://www.flickr.com/people/72869172@N08',
#    'credit': 'Båt med figur, omgiven av en ram',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ef/B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012b.jpg/960px-B%C3%A5t_med_figur%2C_omgiven_av_en_ram_2012b.jpg',
#    'author_name': 'MjauMjauMjauMjau',
#    'author_url': 'https://www.flickr.com/people/72869172@N08',
#    'credit': 'Båt med figur, omgiven av en ram',
#    'license': 'CC BY-SA 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Liljeholmens_grill.JPG/1200px-Liljeholmens_grill.JPG',
#    'author_name': 'Erik Brattlöf',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c6/Skylt_p%C3%A5_Golv%2C_Gallerian_Liljeholmen.jpg/960px-Skylt_p%C3%A5_Golv%2C_Gallerian_Liljeholmen.jpg',
#    'author_name': 'IngimarE',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:IngimarE',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Nybohovshissen%2C_20240210_-_11.jpg/1200px-Nybohovshissen%2C_20240210_-_11.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Nybohovshissen%2C_20240210_-_10.jpg/1200px-Nybohovshissen%2C_20240210_-_10.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Liljeholmen_tunnelbana%2C_SL_C30%2C_20240210_-_14.jpg/1200px-Liljeholmen_tunnelbana%2C_SL_C30%2C_20240210_-_14.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Liljeholmen%2C_CX-tunnelbana%2C_20240210_-_37.jpg/960px-Liljeholmen%2C_CX-tunnelbana%2C_20240210_-_37.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/85/Liljeholmen%2C_SL_C30_tunnelbana%2C_20240210_-_61.jpg/1200px-Liljeholmen%2C_SL_C30_tunnelbana%2C_20240210_-_61.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Czech_bernard_beer_in_Sweden.jpg/960px-Czech_bernard_beer_in_Sweden.jpg',
#    'author_name': 'Aysello',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Aysello&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/9/96/Gullmarsplans_torg_1.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': '',
#    'license': 'CC BY-SA 2.5',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.5'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/Gullmarsplans_torg_2.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': '',
#    'license': 'CC BY-SA 2.5',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.5'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/e/e4/Gullmarsplans_torg_3.jpg',
#    'author_name': None,
#    'author_url': None,
#    'credit': '',
#    'license': 'CC BY-SA 2.5',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/2.5'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/EU-SE-Stockholm-Gullmarsplan_001.JPG/1200px-EU-SE-Stockholm-Gullmarsplan_001.JPG',
#    'author_name': 'Dmitry G',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Dmitry_G',
#    'credit': 'Own work',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/EU-SE-Stockholm-Gullmarsplan_002.JPG/1200px-EU-SE-Stockholm-Gullmarsplan_002.JPG',
#    'author_name': 'Dmitry G',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Dmitry_G',
#    'credit': 'Own work',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Grilltorget%2C_Gullmarsplan%2C_Stockholm.jpg/1200px-Grilltorget%2C_Gullmarsplan%2C_Stockholm.jpg',
#    'author_name': 'golonka66',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Gullmarsplan-2.jpg/1200px-Gullmarsplan-2.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Gullmarsplan-1.jpg/1200px-Gullmarsplan-1.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg/1200px-Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg',
#    'author_name': 'johanarthur',
#    'author_url': 'https://unsplash.com/@johanarthur',
#    'credit': 'https://unsplash.com/photos/eVQxIh6Psh0\nImage at the Wayback Machine\n\nGallery at the Wayback Machine',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/C20F_2000_Elvira.jpg/1200px-C20F_2000_Elvira.jpg',
#    'author_name': 'Anton Lidström',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Antonlidstrom71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/EU-SE-Stockholm-Gullmarsplan_001.JPG/1200px-EU-SE-Stockholm-Gullmarsplan_001.JPG',
#    'author_name': 'Dmitry G',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Dmitry_G',
#    'credit': 'Own work',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/GasregulatorVolvo-1.JPG/1200px-GasregulatorVolvo-1.JPG',
#    'author_name': 'Patrik Nylin',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Pny71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/28/GasregulatorVolvo-2.JPG/1200px-GasregulatorVolvo-2.JPG',
#    'author_name': 'Patrik Nylin',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Pny71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm.jpg/1200px-Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm.jpg',
#    'author_name': 'golonka66',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/95/Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm_2.jpg/1200px-Kebab%2C_Korv_dygnet_runt%2C_Gullmarsplan%2C_Stockholm_2.jpg',
#    'author_name': 'golonka66',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Golonka66&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Gullmarsplan-2.jpg/1200px-Gullmarsplan-2.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Gullmarsplan-1.jpg/1200px-Gullmarsplan-1.jpg',
#    'author_name': 'Alexey M.',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Alexey_M.',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg/1200px-Gullmarsplan%2C_Sweden_%28Unsplash%29.jpg',
#    'author_name': 'johanarthur',
#    'author_url': 'https://unsplash.com/@johanarthur',
#    'credit': 'https://unsplash.com/photos/eVQxIh6Psh0\nImage at the Wayback Machine\n\nGallery at the Wayback Machine',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/C20F_2000_Elvira.jpg/1200px-C20F_2000_Elvira.jpg',
#    'author_name': 'Anton Lidström',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Antonlidstrom71&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/Sp%C3%A4rren_i_Gullmarsplan%2C_20220930.jpg/1200px-Sp%C3%A4rren_i_Gullmarsplan%2C_20220930.jpg',
#    'author_name': 'AleWi',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:AleWi',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Angie_Stone_2010.jpg/1200px-Angie_Stone_2010.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'Flickr: IMG_1257',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/11/Berns_IMG_9205_%284399640858%29.jpg/1200px-Berns_IMG_9205_%284399640858%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9205-1',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Berns_IMG_9127_%284398877683%29.jpg/1200px-Berns_IMG_9127_%284398877683%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9127',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/Berns_IMG_9136_%284399642780%29.jpg/1200px-Berns_IMG_9136_%284399642780%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9136',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/37/Berns_IMG_9230_%284398809801%29.jpg/1200px-Berns_IMG_9230_%284398809801%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9230',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Berns_IMG_9220_%284398834113%29.jpg/1200px-Berns_IMG_9220_%284398834113%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9220',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Berns_IMG_1247_%284399639040%29.jpg/1200px-Berns_IMG_1247_%284399639040%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_1247',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Berns_IMG_9219_%284398841579%29.jpg/1200px-Berns_IMG_9219_%284398841579%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_9219',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Berns_IMG_1272_%284398851919%29.jpg/1200px-Berns_IMG_1272_%284398851919%29.jpg',
#    'author_name': 'Bengt Nyman',
#    'author_url': 'https://www.flickr.com/people/97469566@N00',
#    'credit': 'IMG_1272',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Weyes_Blood_at_Berns%2C_Stockholm%2C_Sweden.jpg/977px-Weyes_Blood_at_Berns%2C_Stockholm%2C_Sweden.jpg',
#    'author_name': 'Juchanwonderland',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Juchanwonderland&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/2012_Ssangyong_Actyons_Sports_D200S_%28Stockholm%29.jpg/1200px-2012_Ssangyong_Actyons_Sports_D200S_%28Stockholm%29.jpg',
#    'author_name': 'Mr.choppers',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Mr.choppers',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/2012_Ssangyong_Actyons_Sports_D200S_rear.jpg/1200px-2012_Ssangyong_Actyons_Sports_D200S_rear.jpg',
#    'author_name': 'Mr.choppers',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Mr.choppers',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/f/f5/Folkungagatan_1963.jpg',
#    'author_name': 'Håkan Trapp',
#    'author_url': 'https://www.wikidata.org/wiki/Q6214850',
#    'credit': 'http://www.stockholmskallan.se/Soksida/Post/?nid=27580',
#    'license': 'Public domain',
#    'license_url': ''},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/9/95/B%C3%A5tsmannen.jpg',
#    'author_name': 'Mamma p',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Mamma_p&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Katarina-Sofia%2C_S%C3%B6dermalm%2C_Stockholm%2C_Sweden_-_panoramio_%282%29.jpg/1200px-Katarina-Sofia%2C_S%C3%B6dermalm%2C_Stockholm%2C_Sweden_-_panoramio_%282%29.jpg',
#    'author_name': 'victorvilkancis@gmai…',
#    'author_url': 'https://web.archive.org/web/20161026054557/http://www.panoramio.com/user/6848960?with_photo_id=70414358',
#    'credit': 'https://web.archive.org/web/20161026054555/http://www.panoramio.com/photo/70414358',
#    'license': 'CC BY 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Tj%C3%A4rhovsgatan_7%2C_2017.jpg/1200px-Tj%C3%A4rhovsgatan_7%2C_2017.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Tj%C3%A4rhovsgatan_7%2C_2017b.jpg/1200px-Tj%C3%A4rhovsgatan_7%2C_2017b.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d1/Sifwertska_kasernen_april%2C_2019e.jpg/1200px-Sifwertska_kasernen_april%2C_2019e.jpg',
#    'author_name': 'Holger.Ellgaard',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Holger.Ellgaard',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Dagakarlen_38.jpg/960px-Dagakarlen_38.jpg',
#    'author_name': 'Jimandersson1',
#    'author_url': 'https://commons.wikimedia.org/w/index.php?title=User:Jimandersson1&action=edit&redlink=1',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ae/%C3%96stg%C3%B6tagatan-Folkungagatan.jpg/960px-%C3%96stg%C3%B6tagatan-Folkungagatan.jpg',
#    'author_name': 'VisbyStar',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:VisbyStar',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Dansens_hus01.jpg/1200px-Dansens_hus01.jpg',
#    'author_name': 'Esquilo',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Esquilo',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Barnhusgatan_8.JPG/1200px-Barnhusgatan_8.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Folkets_hus%2C_Stockholm_2014.JPG/1200px-Folkets_hus%2C_Stockholm_2014.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Kongresser_Konserter_Utst%C3%A4llningar_%2815177592350%29.jpg/1200px-Kongresser_Konserter_Utst%C3%A4llningar_%2815177592350%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Kongresser Konserter Utställningar',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Dansens_Hus_%2815893044326%29.jpg/1200px-Dansens_Hus_%2815893044326%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Dansens Hus',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Barnhusgatan_%2815733097387%29.jpg/1200px-Barnhusgatan_%2815733097387%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Barnhusgatan',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Dansens_Hus_%2815296599384%29.jpg/1200px-Dansens_Hus_%2815296599384%29.jpg',
#    'author_name': 'Tony Webster',
#    'author_url': 'https://www.flickr.com/people/87296837@N00',
#    'credit': 'Dansens Hus',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Barnhuset_20%2C_Stockholm.JPG/1200px-Barnhuset_20%2C_Stockholm.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Stockholm%2C_Sweden_%28Unsplash_3aVlWP-7bg8%29.jpg/1200px-Stockholm%2C_Sweden_%28Unsplash_3aVlWP-7bg8%29.jpg',
#    'author_name': 'mikael_k',
#    'author_url': 'https://unsplash.com/@mikael_k',
#    'credit': 'https://unsplash.com/photos/3aVlWP-7bg8\nImage at the Wayback Machine\n\nGallery at the Wayback Machine',
#    'license': 'CC0',
#    'license_url': 'http://creativecommons.org/publicdomain/zero/1.0/deed.en'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Folkets_hus%2C_Stockholm_2018.jpg/1200px-Folkets_hus%2C_Stockholm_2018.jpg',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'}],
#  [{'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/Filadelfiakyrkan_stockholm.JPG/1200px-Filadelfiakyrkan_stockholm.JPG',
#    'author_name': 'Haxpett',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Haxpett',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Filadelfiakyrkan_stockholm_framsida.JPG/1200px-Filadelfiakyrkan_stockholm_framsida.JPG',
#    'author_name': 'Haxpett',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:Haxpett',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/R%C3%B6rstrandsgatan_4-6.JPG/1200px-R%C3%B6rstrandsgatan_4-6.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/R%C3%B6rstrandsgrillen.JPG/1200px-R%C3%B6rstrandsgrillen.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Stengodset_24.JPG/1200px-Stengodset_24.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/58/Gjutaren_26.JPG/1200px-Gjutaren_26.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/View_of_northern_Kungsholmen_-_panoramio.jpg/1200px-View_of_northern_Kungsholmen_-_panoramio.jpg',
#    'author_name': 'Knutars',
#    'author_url': 'https://web.archive.org/web/20161011041008/http://www.panoramio.com/user/637704?with_photo_id=3143618',
#    'credit': 'https://web.archive.org/web/20161011041006/http://www.panoramio.com/photo/3143618',
#    'license': 'CC BY-SA 3.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Stengodset_18%2C_Stockholm.JPG/1200px-Stengodset_18%2C_Stockholm.JPG',
#    'author_name': 'I99pema',
#    'author_url': 'https://commons.wikimedia.org/wiki/User:I99pema',
#    'credit': 'Own work',
#    'license': 'CC BY-SA 4.0',
#    'license_url': 'https://creativecommons.org/licenses/by-sa/4.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Bakgrunden_i_fokus_-_Flickr_-_nilsw.jpg/960px-Bakgrunden_i_fokus_-_Flickr_-_nilsw.jpg',
#    'author_name': 'Nils Weinander',
#    'author_url': 'https://www.flickr.com/people/42159086@N08',
#    'credit': 'Bakgrunden i fokus',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'},
#   {'photo_url_thumb': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fc/R%C3%B6rstrands_Porslinsfabriker_%286305359137%29.jpg/1200px-R%C3%B6rstrands_Porslinsfabriker_%286305359137%29.jpg',
#    'author_name': 'Tekniska museet',
#    'author_url': 'https://www.flickr.com/people/59292810@N07',
#    'credit': 'Rörstrands Porslinsfabriker',
#    'license': 'CC BY 2.0',
#    'license_url': 'https://creativecommons.org/licenses/by/2.0'}]]

# %%
m = folium.Map(location=[coordinates[1], coordinates[0]], zoom_start=12)

def create_layer_structure(group_key, group_name, group_color, data_lists, data_labels, data_icons):
    group_layer = {"label": group_key, "select_all_checkbox": True, "children": []}
    
    for data_list, data_label, data_icon in zip(data_lists, data_labels, data_icons):
        sublayer = folium.FeatureGroup(name=f"{data_label} ({group_name})")
        

        for df in data_list:  
            for _, row in df.iterrows():
                item_pop_percentage = f"{row['item_pop'] * 100:.4f}%"

   
                photo_infos = row.get("photo_infos", [])
                images_html = ""

                if photo_infos and isinstance(photo_infos, list) and len(photo_infos) > 0:
                    for idx, photo_info in enumerate(photo_infos):
                        img_url = photo_info.get("photo_url_thumb", "")
                        license = photo_info.get("license", "Unknown")
                        license_url = photo_info.get("license_url", "")
                        author_name = photo_info.get("author_name", "Unknown")
                        author_url = photo_info.get("author_url", "")

                        active_class = "active" if idx == 0 else ""
                        caption_html = f"""
                            <div class="text-center" style="font-size: 0.75rem; margin-top: 4px;">
                                <a href="{photo_info.get('photo_url_thumb', '#')}" target="_blank">View Photo</a><br>
                                © <a href="{author_url}" target="_blank">{author_name}</a>,
                                <a href="{license_url}" target="_blank">{license}</a> (no changes made)
                            </div>
                        """

                        images_html += f"""
                            <div class="carousel-item {active_class}">
                                <img src="{img_url}" class="d-block w-100" style="max-height: 200px; object-fit: contain;" alt="POI Image">
                                {caption_html}
                            </div>
                        """

                    carousel_html = f"""
                        <div id="carousel-{row['item_id:token']}" class="carousel slide" data-bs-ride="carousel" style="max-height: 250px; overflow: hidden;">
                            <div class="carousel-inner">
                                {images_html}
                            </div>
                            <a class="carousel-control-prev" href="#carousel-{row['item_id:token']}" role="button" data-bs-slide="prev">
                                <span class="carousel-control-prev-icon" aria-hidden="true"></span>
                                <span class="visually-hidden">Previous</span>
                            </a>
                            <a class="carousel-control-next" href="#carousel-{row['item_id:token']}" role="button" data-bs-slide="next">
                                <span class="carousel-control-next-icon" aria-hidden="true"></span>
                                <span class="visually-hidden">Next</span>
                            </a>
                        </div>
                    """
                else:
                    carousel_html = "<p><i>No images available</i></p>"

                popup_content = f"""
                    <b>User ID:</b> {user_samples[group_key]} <br>
                    <b>POI ID:</b> {row['item_id:token']}<br>
                    <b>POI Popularity:</b> {item_pop_percentage}<br>
                    <b>Data Type:</b> {data_label}<br>
                    <b>User Group:</b> {group_key} <br>
                    {carousel_html}
                """

                folium.Marker(
                    location=(row.geometry.y, row.geometry.x),
                    popup=folium.Popup(popup_content, max_width=300),
                    icon=folium.Icon(color=group_color, icon=data_icon, prefix="glyphicon"),
                ).add_to(sublayer)
        
        group_layer["children"].append({"label": data_label, "layer": sublayer})
        sublayer.add_to(m)
    
    return group_layer


user_samples = {"HighPop": "481_x", "MedPop": "1023_x", "LowPop": "130_x"}
color_scheme = ["darkpurple", "blue", "green"]
data_lists = [training_data_list, baseline_list, cp_list, context_list]
data_labels = ["Training Data", "Baseline", "Calibrated Popularity", "Context-Aware"]
data_icons = ["glyphicon glyphicon-cog", "glyphicon glyphicon-star-empty", "glyphicon-repeat", "glyphicon-eye-open"]

overlay_tree = {"label": "User Groups", "select_all_checkbox": "Select/Deselect All", "children": []}

for group_idx, (group_key, group_name, group_color) in enumerate(zip(user_samples.keys(), user_samples.values(), color_scheme)):

    data_lists_for_group = [
        [training_data_list[group_idx]],  # Training data for the current group
        [baseline_list[group_idx]],      # Baseline recommendations for the current group
        [cp_list[group_idx]],            # CP recommendations for the current group
        [context_list[group_idx]],       # Context-aware recommendations for the current group
    ]
    

    overlay_tree["children"].append(
        create_layer_structure(group_key, group_name, group_color, data_lists_for_group, data_labels, data_icons)
    )

# Add 20 km buffer as a circle (adjust coordinates as needed)
folium.Circle(
    location=coordinates,
    radius=20000,
    color="red",
    fill=False,
    fill_opacity=0.2,
).add_to(m)

# Add TreeLayerControl for filtering layers
TreeLayerControl(overlay_tree=overlay_tree).add_to(m)

legend_html = """
<div style="position: fixed; bottom: 50px; left: 50px; width: 220px; height: auto;
            background-color: white; border: 2px solid grey; z-index: 9999; font-size: 14px;
            padding: 10px; box-shadow: 2px 2px 10px rgba(0,0,0,0.2);">
    
    <b>About This Tool</b> <br>
    <button class="btn btn-info btn-sm" type="button" data-bs-toggle="collapse" data-bs-target="#aboutTool">More Info</button>
    <div id="aboutTool" class="collapse" style="margin-top: 5px;">
        This demo is part of a master's thesis on popularity bias mitigation in POI recommender systems. 
        We chose three users from the Gowalla dataset around Stockhom and visualize the places they visited in the past & the recommendations they received from different algorithms.
    </div>
    
    <hr>
    
    <b><i class="glyphicon glyphicon-user"></i> User Groups</b> <br>
    <button class="btn btn-secondary btn-sm" type="button" data-bs-toggle="collapse" data-bs-target="#userGroups">Learn More</button>
    <div id="userGroups" class="collapse" style="margin-top: 5px;">
        Users are divided into three groups based on check-in popularity:<br>
        <b style="color: green;"><i class="glyphicon glyphicon-user"></i> LowPop</b> <br>
        <b style="color: blue;"><i class="glyphicon glyphicon-user"></i> MedPop</b> <br>
        <b style="color: purple;"><i class="glyphicon glyphicon-user"></i> HighPop</b> <br>
        
    </div>
    
    <hr>
    
    <b><i class="glyphicon glyphicon-cog"></i> Training Data</b> <br>
    <button class="btn btn-secondary btn-sm" type="button" data-bs-toggle="collapse" data-bs-target="#trainingData">Learn More</button>
    <div id="trainingData" class="collapse" style="margin-top: 5px;">
        Locations that a user has visited in the past, used to calculate future recommendations.
    </div>
    
    <hr>
    
    <b><i class="glyphicon glyphicon-signal"></i> Recommendation Algorithms</b> <br>
    <button class="btn btn-secondary btn-sm" type="button" data-bs-toggle="collapse" data-bs-target="#algorithms">Learn More</button>
    <div id="algorithms" class="collapse" style="margin-top: 5px;">
        <b><i class="glyphicon glyphicon-star-empty"></i> Baseline:</b> Standard model (BPR). Recommends many popular places <br>
        <b><i class="glyphicon glyphicon-repeat"></i> Calibrated Popularity:</b> Adjusts recommendations to match user’s past preferences. <br>
        <b><i class="glyphicon glyphicon-eye-open"></i> Context-Aware POI Recommender:</b> Uses LORE algorithm to factor in time, geography, and visit sequences. Recommends many niche places.
    </div>
</div>

"""

legend = Element(legend_html)
m.get_root().html.add_child(legend)

m.save("poi_visualization_demo_tool.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43692932e84e72f6fbdb50d15d9d6ec8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.control.layers.tree@1.1.0/L.Control.Layers.Tree.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.control.layers.tree@1.1.0/L.Control.Layers.Tree.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; width: 220px; height: auto;
#             background-color: white; border: 2px solid grey; z-index: 9999; font-size: 14px;
#             padding: 10px; box-shadow: 2px 2px 10px rgba(0,0,0,0.2);&quot;&gt;
#
#     &lt;b&gt;About This Tool&lt;/b&gt; &lt;br&gt;
#     &lt;button class=&quot;btn btn-info btn-sm&quot; type=&quot;button&quot; data-bs-toggle=&quot;collapse&quot; data-bs-target=&quot;#aboutTool&quot;&gt;More Info&lt;/button&gt;
#     &lt;div id=&quot;aboutTool&quot; class=&quot;collapse&quot; style=&quot;margin-top: 5px;&quot;&gt;
#         This demo is part of a master&#x27;s thesis on popularity bias mitigation in POI recommender systems.
#         We chose three users from the Gowalla dataset around Stockhom and visualize the places they visited in the past &amp; the recommendations they received from different algorithms.
#     &lt;/div&gt;
#
#     &lt;hr&gt;
#
#     &lt;b&gt;&lt;i class=&quot;glyphicon glyphicon-user&quot;&gt;&lt;/i&gt; User Groups&lt;/b&gt; &lt;br&gt;
#     &lt;button class=&quot;btn btn-secondary btn-sm&quot; type=&quot;button&quot; data-bs-toggle=&quot;collapse&quot; data-bs-target=&quot;#userGroups&quot;&gt;Learn More&lt;/button&gt;
#     &lt;div id=&quot;userGroups&quot; class=&quot;collapse&quot; style=&quot;margin-top: 5px;&quot;&gt;
#         Users are divided into three groups based on check-in popularity:&lt;br&gt;
#         &lt;b style=&quot;color: green;&quot;&gt;&lt;i class=&quot;glyphicon glyphicon-user&quot;&gt;&lt;/i&gt; LowPop&lt;/b&gt; &lt;br&gt;
#         &lt;b style=&quot;color: blue;&quot;&gt;&lt;i class=&quot;glyphicon glyphicon-user&quot;&gt;&lt;/i&gt; MedPop&lt;/b&gt; &lt;br&gt;
#         &lt;b style=&quot;color: purple;&quot;&gt;&lt;i class=&quot;glyphicon glyphicon-user&quot;&gt;&lt;/i&gt; HighPop&lt;/b&gt; &lt;br&gt;
#
#     &lt;/div&gt;
#
#     &lt;hr&gt;
#
#     &lt;b&gt;&lt;i class=&quot;glyphicon glyphicon-cog&quot;&gt;&lt;/i&gt; Training Data&lt;/b&gt; &lt;br&gt;
#     &lt;button class=&quot;btn btn-secondary btn-sm&quot; type=&quot;button&quot; data-bs-toggle=&quot;collapse&quot; data-bs-target=&quot;#trainingData&quot;&gt;Learn More&lt;/button&gt;
#     &lt;div id=&quot;trainingData&quot; class=&quot;collapse&quot; style=&quot;margin-top: 5px;&quot;&gt;
#         Locations that a user has visited in the past, used to calculate future recommendations.
#     &lt;/div&gt;
#
#     &lt;hr&gt;
#
#     &lt;b&gt;&lt;i class=&quot;glyphicon glyphicon-signal&quot;&gt;&lt;/i&gt; Recommendation Algorithms&lt;/b&gt; &lt;br&gt;
#     &lt;button class=&quot;btn btn-secondary btn-sm&quot; type=&quot;button&quot; data-bs-toggle=&quot;collapse&quot; data-bs-target=&quot;#algorithms&quot;&gt;Learn More&lt;/button&gt;
#     &lt;div id=&quot;algorithms&quot; class=&quot;collapse&quot; style=&quot;margin-top: 5px;&quot;&gt;
#         &lt;b&gt;&lt;i class=&quot;glyphicon glyphicon-star-empty&quot;&gt;&lt;/i&gt; Baseline:&lt;/b&gt; Standard model (BPR). Recommends many popular places &lt;br&gt;
#         &lt;b&gt;&lt;i class=&quot;glyphicon glyphicon-repeat&quot;&gt;&lt;/i&gt; Calibrated Popularity:&lt;/b&gt; Adjusts recommendations to match user’s past preferences. &lt;br&gt;
#         &lt;b&gt;&lt;i class=&quot;glyphicon glyphicon-eye-open&quot;&gt;&lt;/i&gt; Context-Aware POI Recommender:&lt;/b&gt; Uses LORE algorithm to factor in time, geography, and visit sequences. Recommends many niche places.
#     &lt;/div&gt;
# &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43692932e84e72f6fbdb50d15d9d6ec8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43692932e84e72f6fbdb50d15d9d6ec8 = L.map(
#                 &quot;map_43692932e84e72f6fbdb50d15d9d6ec8&quot;,
#                 {
#                     center: [59.329, 18.0686],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56cdc436494424ae6694b534a9854087 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56cdc436494424ae6694b534a9854087.addTo(map_43692932e84e72f6fbdb50d15d9d6ec8);
#
#
#             var feature_group_6781dac57e9ce85f0797045a68fa6c7c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e7f2134537229aff0f43fdebd874a716 = L.marker(
#                 [59.33015770000001, 18.0580794811],
#                 {
# }
#             ).addTo(feature_group_6781dac57e9ce85f0797045a68fa6c7c);
#
#
#             var icon_bed410e38ae9e1
